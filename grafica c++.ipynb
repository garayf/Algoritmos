# %%
import matplotlib.pyplot as plt
import numpy as np
from time import time


grafica =np.array([0.000853, 0.000052, 0.000032, 0.000022, 0.0000182, 0.0000167, 0.000015, 0.000002, 0.0000015, 0.0000008, 0.0000004, 0.00000002 ])
numero=np.array([5,10,15,20,25,30,35,40])
print (grafica)
plt.plot(grafica)
# Out:
# [  8.53000000e-04   5.20000000e-05   3.20000000e-05   2.20000000e-05
#    1.82000000e-05   1.67000000e-05   1.50000000e-05   2.00000000e-06
#    1.50000000e-06   8.00000000e-07   4.00000000e-07   2.00000000e-08]
